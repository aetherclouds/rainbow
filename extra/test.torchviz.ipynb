# %%
import torch
from torchviz import make_dot
x=torch.ones(2, requires_grad=True)
y=2*x
print(x.shape)
z=(3+x)-x.mean()
r=(y+z).sum()
make_dot(r)
# Out:
# torch.Size([2])

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.ion()

error1 = [1, 2]
error2 = [4, 5]
x = np.arange(len(error))

plt.fill_between(x, error1, error2)
# Out:
# [0 1]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 8
#       5 error = [1, 2]
#       6 print(np.arange(len(error)))
# ----> 8 plt.fill_between(list(range(error)), error, [3, 4])
#
# TypeError: 'list' object cannot be interpreted as an integer
